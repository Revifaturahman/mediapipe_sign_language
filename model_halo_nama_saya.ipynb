# %%
import pandas as pd
import glob
from sklearn.ensemble import RandomForestClassifier
import pickle

# Baca semua file CSV yang dimulai dengan 'gesture_dataset'
all_files = glob.glob("gesture_dataset_*.csv")

# Gabungkan semua ke dalam satu DataFrame
df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)

# Cek isi datanya
print(df['label'].value_counts())
df.head()
# Out:
# label
# halo    50
# nama    50
# saya    50
# Name: count, dtype: int64
#          x0        y0            z0        x1        y1        z1        x2  \
# 0  0.803064  0.661337  4.543832e-07  0.723115  0.622369 -0.028493  0.657646
# 1  0.624250  0.670611  4.835772e-07  0.543677  0.693544 -0.030064  0.463913
# 2  0.595068  0.718752  3.849658e-07  0.521920  0.673861 -0.027096  0.464543
# 3  0.826014  0.531151  4.093070e-07  0.757037  0.497793 -0.024599  0.693968
# 4  0.514047  0.579888  5.000069e-07  0.443897  0.560419 -0.029768  0.387736
#
#          y2        z2        x3  ...       x18       y18       z18       x19  \
# 0  0.549488 -0.042896  0.614349  ...  0.883945  0.343569 -0.074643  0.902461
# 1  0.671321 -0.046134  0.399403  ...  0.584564  0.356120 -0.076235  0.584230
# 2  0.592397 -0.045022  0.419610  ...  0.704946  0.422456 -0.093681  0.728015
# 3  0.437705 -0.036122  0.650367  ...  0.882390  0.254323 -0.058144  0.899275
# 4  0.519787 -0.052112  0.347956  ...  0.579622  0.282497 -0.090116  0.592968
#
#         y19       z19       x20       y20       z20  label
# 0  0.290440 -0.083663  0.917429  0.239573 -0.089512   halo
# 1  0.297258 -0.084994  0.579623  0.244170 -0.090847   halo
# 2  0.366525 -0.104395  0.746356  0.314204 -0.111197   halo
# 3  0.206987 -0.066659  0.913434  0.163482 -0.071486   halo
# 4  0.227167 -0.097813  0.602150  0.176194 -0.102365   halo
#
# [5 rows x 64 columns]

# %%
X = df.drop("label", axis=1)
y = df["label"]

model = RandomForestClassifier()
model.fit(X, y)

# Simpan model
with open("gesture_model.pkl", "wb") as f:
    pickle.dump(model, f)
